# %% [markdown]
# - 총 2445개
# - "빅데이터" 검색,  KCI 등재(실행)
# - http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%22%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%22&exQuery=regnm%3AKCI%EB%93%B1%EC%9E%AC%E2%97%88&exQueryText=%EB%93%B1%EC%9E%AC%EC%A0%95%EB%B3%B4+%5BKCI%EB%93%B1%EC%9E%AC%5D%40%40regnm%3AKCI%EB%93%B1%EC%9E%AC%E2%97%88&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount=2400&orderBy=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=&resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_a_kor&colName=re_a_kor&pageScale=100&isTab=Y&query=%22%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%22

# %% [markdown]
# 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%22%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%22\
#             &exQuery=regnm%3AKCI%EB%93%B1%EC%9E%AC%E2%97%88&exQueryText=%EB%93%B1%EC%9E%AC%EC%A0%95%EB%B3%B4+%5BKCI%EB%93%B1%EC%9E%AC%5D%40%40regnm%3AKCI%EB%93%B1%EC%9E%AC%E2%97%88\
#             &order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=\
#             &iStartCount={}\
#             &orderBy=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=\
#             &resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_a_kor&colName=re_a_kor\
#             &pageScale=100&isTab=Y&query=%22%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%22\'.format(i)

# %%
import pandas as pd
import numpy as np

#!pip install tqdm
from tqdm import tqdm
import lxml.html
import requests

# %%
page = list(range(0, 2500, 100))

RISS_url_list = []

for i in tqdm(page):
    
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%22%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%22&exQuery=regnm%3AKCI%EB%93%B1%EC%9E%AC%E2%97%88&exQueryText=%EB%93%B1%EC%9E%AC%EC%A0%95%EB%B3%B4+%5BKCI%EB%93%B1%EC%9E%AC%5D%40%40regnm%3AKCI%EB%93%B1%EC%9E%AC%E2%97%88&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=''&iStartCount={}&orderBy=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=&resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_a_kor&colName=re_a_kor&pageScale=100&isTab=Y&query=%22%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%22'\
                    .format(i)
    
    response = requests.get(url)

    root = lxml.html.fromstring(response.content)

    for li in root.xpath('//*[@id="divContent"]/div[2]/div/div[3]/div[2]/ul/li'):
        a = li.xpath('div[2]/p[1]/a')[0]
        url = a.get('href')
        RISS_url_list.append('http://www.riss.kr' + url)

print('총 url 개수 : ', len(np.unique(RISS_url_list)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:28<00:00,  1.16s/it]
# 총 url 개수 :  2443

# %% [markdown]
# # 크롤링 내용들 넣을 데이터프레임 생성
# 1. 제목
# 2. 발행연도
# 3. 주제어
# 4. 발행기관
# 5. 상세조회수
# 6. 다운로드
# 7. KCI 피인용횟수

# %%
RISS_url_list
# Out:
# ['http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=415b9a2c361b82677f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=08510ea66878089d4884a65323211ff0',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=e544147e8f193f037ecd42904f0c5d65',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=37a6deaebdfec22bd18150b21a227875',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=0b433c70dbad63c86aae8a972f9116fb',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=f6cb85e31578ecd84884a65323211ff0',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=750706c19b84dd23d18150b21a227875',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=4195865c42c01f77b36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=45c54b9a3704b5647f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=da5cc339715253a1ffe0bdc3ef48d419',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=6e701fa51c15137be9810257f7042666',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=fc901c3ccf8718384884a65323211ff0',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=d9fc1bf2b68968027ecd42904f0c5d65',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=adf7c54f99c2d9717f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=29bdc65e0793446147de9c1710b0298d',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=6dbd2725ce4809f2c85d2949c297615a',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=f4f81d6c31b4cfc2d18150b21a227875',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=6dad07c6e4212525ffe0bdc3ef48d419',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=9a5851ca09309fcab7998d826d417196',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=3de27a51b8f7098d7f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=128eb856bd939f81d18150b21a227875',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=d6e3e2afa7c8d992e9810257f7042666',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=d3e3fb15324eec486aae8a972f9116fb',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=b657d0ef0781d585d18150b21a227875',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=9ce41110d1d8807f7ecd42904f0c5d65',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=20e0ec9122f3c6687f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=29a3282b734419e1b36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=47fa972fb20508fc6aae8a972f9116fb',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=e2d775c98426519fb36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=091bf8f6e3afc304b36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=517f269c0387efa6c85d2949c297615a',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=53bf8bb7f6a5cd65b36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=6fd71ad166f297a247de9c1710b0298d',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=61f5f4065c936dc97f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=7ede8e68d829b6bbb36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=386fa362fd0ea26d7ecd42904f0c5d65',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=a6d0853b344bb7567f7a54760bb41745',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=269823033dbb55dc47de9c1710b0298d',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=b1e4664962729f8affe0bdc3ef48d419',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=065d0551e62c645db7998d826d417196',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=a876e50ecee0383d4884a65323211ff0',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=d5e1c3febf7468974884a65323211ff0',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=76b6d409d38d080847de9c1710b0298d',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=1d5560a206e78a50b36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=5fbef365b29fb5a2b36097776a77e665',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=256a625a52d8fa53d18150b21a227875',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=e28f9c1d0bfe64fd47de9c1710b0298d',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=652e15a1547b4f57e9810257f7042666',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=f39534cd6e7cc23bffe0bdc3ef48d419',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=e26189f838aa7428e9810257f7042666',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=0fbf0746a3c4e8cdb7998d826d417196',
#  'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=
http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=70ea2dc1acc0eaa2ffe0bdc3ef48d419',
#  ...]

# %%
df = pd.DataFrame({'url' : RISS_url_list})

df.loc[:, '제목'] = '.'            #1
df.loc[:, '발행연도'] = '.'        #2 
df.loc[:, '주제어'] = '.'          #3 
df.loc[:, '발행기관'] = '.'        #4   
df.loc[:, '상세조회수'] = '.'      #5
df.loc[:, '다운로드수'] = '.'      #6
df.loc[:, 'KCI 피인용횟수'] = '.'  #7

df
# Out:
#                                                     url 제목 발행연도 주제어 발행기관  \
# 0     http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 1     http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 2     http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 3     http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 4     http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# ...                                                 ... ..  ...  ..  ...
# 2439  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 2440  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 2441  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 2442  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
# 2443  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .
#
#      상세조회수 다운로드수 KCI 피인용횟수
# 0        .     .         .
# 1        .     .         .
# 2        .     .         .
# 3        .     .         .
# 4        .     .         .
# ...    ...   ...       ...
# 2439     .     .         .
# 2440     .     .         .
# 2441     .     .         .
# 2442     .     .         .
# 2443     .     .         .
#
# [2444 rows x 8 columns]

# %%
req = requests.get(df['url'][0])
print(req.content)
# Out:
# b'<html>\r\n<body>\r\n<form name="f" method="POST" action="http://sso.riss.kr:11301/cdc_read_relay.jsp">\r\n<input type="hidden" name="SAMLRequest" value="...">\r\n<input type="hidden" name="RelayState" value="http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=415b9a2c361b82677f7a54760bb41745">\r\n</form>\r\n<script language="javascript">\r\nvar relay_flag = true;\r\nfunction goPost() { relay_flag = false; document.f.submit(); }\r\nfunction goRelay() { if(relay_flag) document.location.href = "http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=415b9a2c361b82677f7a54760bb41745"; } \r\nsetTimeout("goRelay()", 500);\r\n</script>\r\n<script language="javascript" src="http://sso.riss.kr:11301/cdc_read_check.jsp"></script>\r\n</body>\r\n</html>\r\n'

# %% [markdown]
# # sellinium

# %%
from selenium import webdriver 

chromedriver = 'chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# # 1번째 행의 url 사용해서 연습
# - a라는 변수에 임의의 하나의 url 넣어줌

# %%
a = df['url'][0]
a
# Out:
# 'http://www.riss.kr/search/detail/DetailView.do?p_mat_type=1a0202e37d52c72d&control_no=415b9a2c361b82677f7a54760bb41745'

# %% [markdown]
# ##### a라는 url chromedriver로 실행

# %%
import time
from bs4 import BeautifulSoup
import re

driver.get(a);
time.sleep(1)         # 

html = driver.page_source                 #driver가 html을 가져오고
soup = BeautifulSoup(html, 'html.parser') #BeautifulSoup으로 파싱?? html 태그를 이쁘게 꾸며줌

# %% [markdown]
# ---

# %%
len(np.unique(df['url']))
# Out:
# 2444

# %%
df.head()
# Out:
#                                                  url 제목 발행연도 주제어 발행기관 상세조회수  \
# 0  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 1  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 2  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 3  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 4  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
#
#   다운로드수 KCI 피인용횟수
# 0     .         .
# 1     .         .
# 2     .         .
# 3     .         .
# 4     .         .

# %% [markdown]
# ##### Column 하나씩 불러온 후 정규화 과정 진행
# 1. 제목
# 2. 발행연도
# 3. 주제어
# 4. 발행기관
# 5. 상세조회수
# 6. 다운로드수
# 7. KCI 피인용횟수

# %% [markdown]
# ### 문제점 : Xpath로하면 안됨.. RISS측에서 막아둔듯

# %% [markdown]
# #soptionview > div > div.thesisInfo > div.thesisInfoTop > h3

# %%
driver.get(a)
driver.implicitly_wait(5)
driver.find_element_by_xpath('//*[@id="soptionview"]/div/div[1]/div[1]/h3')

#여기서 값이 나와야되는데 , 이상한값만 호출됨.
#숨김처리된듯
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="92c2b2da529bc4092843825cf92a27ec", element="c1535ddb-9ded-47ff-b097-cf7df8cf8af9")>

# %% [markdown]
# # 1. 제목
#
# ###### 정규표현식 함수 생성
#     - \s+  : 공백이 한개이상 있으면 , 제거해줌 ('\t와 \n이 너무 많아서 사용함)
#     - 한글만 사용(한글이 아니면 모두 공백으로 대체(sub)시켜줌)
#     - strip : 앞뒤 공백 제거

# %%
제목 = soup.select(
    '#soptionview > div > div.thesisInfo > div.thesisInfoTop > h3'
)[0].text

# %%
soup.select('#soptionview > div > div.thesisInfo > div.thesisInfoTop > h3')[0].text
# Out:
# '\n\t\t\t\t개인정보 보안강화 및 빅데이터 활성화를 위한 새로운 빅데이터 플랫폼 제시\n\t\t\t \t\n\t\t\t \t\n\t\t\t\t\n\t\t        \n\t\t\t'

# %%
def Title_re_function(문장):
    x = re.sub(pattern = '\s+', 
       repl = ' ', 
       string = 문장)

    hangueol_pattern = re.compile(r'[^가-힣]')
    result = hangueol_pattern.sub(' ', x)


    return result.strip()

제목 = Title_re_function(제목)
print(제목)
# Out:
# 개인정보 보안강화 및 빅데이터 활성화를 위한 새로운 빅데이터 플랫폼 제시

# %%
RISS_df
# Out:
#                                                     url  \
# 0     http://www.riss.kr/search/detail/DetailView.do...
# 1     http://www.riss.kr/search/detail/DetailView.do...
# 2     http://www.riss.kr/search/detail/DetailView.do...
# 3     http://www.riss.kr/search/detail/DetailView.do...
# 4     http://www.riss.kr/search/detail/DetailView.do...
# ...                                                 ...
# 2426  http://www.riss.kr/search/detail/DetailView.do...
# 2427  http://www.riss.kr/search/detail/DetailView.do...
# 2428  http://www.riss.kr/search/detail/DetailView.do...
# 2429  http://www.riss.kr/search/detail/DetailView.do...
# 2430  http://www.riss.kr/search/detail/DetailView.do...
#
#                                                      제목  발행연도  \
# 0             빅데이터 유통 생태계에 기반한 단계별 빅데이터 유통 모델 개발에 관한 연구  2016
# 1     실물옵션 기법을 이용한 기업의 빅데이터 기술 도입의 경제적 가치 분석   유유제약 ...  2014
# 2                             빅데이터 에코시스템 기반의 참조 아키텍처 개발  2014
# 3                    공공기관의 빅데이터 성숙도 진단모형 개발 및 적용에 관한 연구  2016
# 4              개인정보 보안강화 및 빅데이터 활성화를 위한 새로운 빅데이터 플랫폼 제시  2016
# ...                                                 ...   ...
# 2426                    융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토  2016
# 2427                           정부기관의 정보열람 요구와    의 협조의무  2016
# 2428                  디지털 플랫폼과   에 의한 국회 전자청원시스템 활성화 연구  2019
# 2429                         천태종 구인사의 종파성 확보를 위한 플랫폼 구도  2019
# 2430                         한국의 데이터주도 혁신에 대한 법의 대응과 진화  2018
#
#                                                     주제어             발행기관  \
# 0     [' 빅데이터 유통 모델 ', ' 데이터 거래 플랫폼 ', ' 빅데이터 거래소 ',...        한국디지털정책학회
# 1     [' 빅데이터 플랫폼 ', ' 실물옵션 ', ' 옵션가치 ', ' 주가 ', ' B...        한국인터넷정보학회
# 2     [' 참조 아키텍처 ', ' 상호운용성 ', ' 표준 ', ' Big data ',...  보안공학연구지원센터(JSE)
# 3                                   [' 성숙도 ', ' 수준진단 ']        한국지역정보화학회
# 4     [' 빅데이터 플랫폼 ', ' 개인정보보호 ', ' 빅데이터 활성화 ', ' HBa...        한국디지털정책학회
# ...                                                 ...              ...
# 2426                                                 []            단국대학교
# 2427                                                 []            경희대학교
# 2428                                                 []           유럽헌법학회
# 2429                                                 []          보조사상연구원
# 2430                                                 []            서울대학교
#
#      상세조회수  다운로드수  KCI피인용횟수
# 0      112    105      13.0
# 1      119    102       5.0
# 2      114     79       NaN
# 3       50     54       1.0
# 4      121     92       6.0
# ...    ...    ...       ...
# 2426     5      4       NaN
# 2427     8      0       1.0
# 2428    10      0       NaN
# 2429     3      0       NaN
# 2430    32     20       5.0
#
# [2431 rows x 8 columns]

# %%
제목
# Out:
# '개인정보 보안강화 및 빅데이터 활성화를 위한 새로운 빅데이터 플랫폼 제시'

# %% [markdown]
# # 2. 발행연도

# %%
발행연도 = soup.select(
    '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
)[4].text

발행연도
# Out:
# '\n발행연도\n2016\n'

# %%
def 발행연도_정제(발행연도):
    num_pattern = re.compile(r'[^0-9]')
    num = num_pattern.sub(' ', 발행연도)
    return num.strip()

발행연도 = 발행연도_정제(발행연도)

# %% [markdown]
# # 3. 주제어

# %%
주제어 = soup.select(
    '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
)[6].text

주제어
# Out:
# '\n주제어\n\n\n\n\t\t\t\t\t\t\t\t빅데이터\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t 빅데이터 플랫폼\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t 개인정보보호\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t 빅데이터 활성화\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t HBase\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t 개인정보관리체계\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t Big Data\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t Big Data Platform\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t Privacy\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t Big Data enabled\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t HBase\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t,\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t PIMS\n\t\t\t\t\t\t\t\t\n\n\n'

# %%
'주제어 , 기계학습 , 기상데이터, 데이터마이닝, 자연재해'.split(',')[1:]
# Out:
# [' 기계학습 ', ' 기상데이터', ' 데이터마이닝', ' 자연재해']

# %%
def 주제어_re_function(문장):
    x = re.sub(pattern = '\s+', 
       repl = ' ', 
       string = 문장)
    
    
    return x.split(',')[1:]

주제어 = 주제어_re_function(주제어)

# %%
주제어
# Out:
# [' 빅데이터 플랫폼 ',
#  ' 개인정보보호 ',
#  ' 빅데이터 활성화 ',
#  ' HBase ',
#  ' 개인정보관리체계 ',
#  ' Big Data ',
#  ' Big Data Platform ',
#  ' Privacy ',
#  ' Big Data enabled ',
#  ' HBase ',
#  ' PIMS ']

# %% [markdown]
# # 4. 발행기관

# %%
#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li

# %%
발행기관 = soup.select(
    '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
)[1]

발행기관
# Out:
# <li>
# <span class="strong">발행기관</span>
# <div><p><a href="/search/Search.do?queryText=znPublisher,%ED%95%9C%EA%B5%AD%EB%94%94%EC%A7%80%ED%84%B8%EC%A0%95%EC%B1%85%ED%95%99%ED%9A%8C&amp;searchGubun=true&amp;colName=re_s&amp;isDetailSearch=Y">한국디지털정책학회</a></p></div>
# </li>

# %%
발행기관.text.split()[1]
# Out:
# '한국디지털정책학회'

# %%
발행기관 = 발행기관.text.split()[1]
발행기관
# Out:
# '한국디지털정책학회'

# %% [markdown]
# ### 5. 상세조회수
# ### 6. 다운로드수

# %%
#상세조회수
상세조회수 = int(soup.select(
    '#f_view'
)[0].text)



#다운로드수
다운로드수 = int(soup.select(
    '#f_usage'
)[0].text)


print('상세조회수 : ', 상세조회수)
print('다운로드수 : ', 다운로드수)
# Out:
# 상세조회수 :  121
# 다운로드수 :  92

# %% [markdown]
# # 7. KCI피인용횟수

# %%
KCI피인용횟수 = soup.select(
    '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
)[-2].text


KCI피인용횟수
# Out:
# '\nKCI 피인용횟수\n6\n'

# %%
def KCI피인용횟수_정제(KCI피인용횟수):
    num_pattern = re.compile(r'[^0-9]')
    num = num_pattern.sub(' ', KCI피인용횟수)
    
    
    if num.strip().count(' ')>0:   # 피인용횟수가 없다면 , 기입이 안되어있음
                                     # 그래서 , 피인용횟수가 0 인것들은, 수록면 데이터를 가져와서 , 공백이 존재함
                                     # 이러한 근거의 지표로 공백의 존재 여부를 활용
        return 0
    else:
        return num.strip()


KCI피인용횟수 = KCI피인용횟수_정제(KCI피인용횟수)
KCI피인용횟수
# Out:
# '6'

# %% [markdown]
# ----

# %% [markdown]
# ### for문으로 본격적인 크롤링

# %% [markdown]
# 1. 제목
# 2. 발행연도
# 3. 주제어
# 4. 발행기관
# 5. 상세조회수
# 6. 다운로드수
# 7. KCI 피인용횟수

# %%
df.head()
# Out:
#                                                  url 제목 발행연도 주제어 발행기관 상세조회수  \
# 0  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 1  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 2  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 3  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
# 4  http://www.riss.kr/search/detail/DetailView.do...  .    .   .    .     .
#
#   다운로드수 KCI 피인용횟수
# 0     .         .
# 1     .         .
# 2     .         .
# 3     .         .
# 4     .         .

# %%
df_list = []

for  url in tqdm(df['url'][1800:]):
    try:
        driver.get(url);
        time.sleep(1)         #

        html = driver.page_source                 #driver가 html을 가져오고
        soup = BeautifulSoup(html, 'html.parser') #BeautifulSoup으로 파싱?? html 태그를 이쁘게 꾸며줌

        제목 = soup.select(
        '#soptionview > div > div.thesisInfo > div.thesisInfoTop > h3'
        )[0].text

        #1. 제목
        제목 = Title_re_function(제목)



        #2. 발행연도
        발행연도 = soup.select(
        '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
            )[4].text

        발행연도= 발행연도_정제(발행연도)


        #3. 주제어
        주제어 = soup.select(
        '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
            )[6].text

        주제어 = 주제어_re_function(주제어)

        #4. 발행기관
        발행기관 = soup.select(
        '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
        )[1]

        발행기관= 발행기관.text.split()[1]            

        #5.상세조회수
        상세조회수 = soup.select(
        '#f_view'
        )[0].text



        #6. 다운로드수
        다운로드수 = int(soup.select(
            '#f_usage'
        )[0].text)



        #7. KCI 인용횟수
        KCI피인용횟수 = soup.select(
            '#soptionview > div > div.thesisInfo > div.infoDetail.on > div.infoDetailL > ul > li'
            )[-2].text


        KCI피인용횟수 = KCI피인용횟수_정제(KCI피인용횟수)


        DF = pd.DataFrame({'url': [url], 
                                     '제목': [제목] ,
                                     '발행연도' : [발행연도] ,
                                     '주제어' : [주제어] , 
                                     '발행기관' : [발행기관],
                                     '상세조회수' : [상세조회수],
                                     '다운로드수' : [다운로드수],
                                     'KCI피인용횟수' : [KCI피인용횟수]
                                    })
        df_list.append(DF)
    except:
        pass
    
RISS_df = pd.concat(df_list)
RISS_df

#db_save(RISS_df)
# Out:
#   1%|▋                                                                                 | 5/644 [00:12<27:27,  2.58s/it]

# %%
RISS_df_Origin = pd.read_csv('RISS_LIST_Origin.csv', index_col = 0)
RISS_df_A = pd.read_csv('RISS_LIST_A.csv', index_col = 0)
RISS_df_B = pd.read_csv('RISS_LIST_B.csv', index_col = 0)
RISS_df_C = pd.read_csv('RISS_LIST_C.csv', index_col = 0)

RISS_df = pd.concat([RISS_df_C, RISS_df_A, RISS_df_B, RISS_df_Origin], ignore_index=True)
RISS_df
# Out:
#                                                     url  \
# 0     http://www.riss.kr/search/detail/DetailView.do...
# 1     http://www.riss.kr/search/detail/DetailView.do...
# 2     http://www.riss.kr/search/detail/DetailView.do...
# 3     http://www.riss.kr/search/detail/DetailView.do...
# 4     http://www.riss.kr/search/detail/DetailView.do...
# ...                                                 ...
# 2426  http://www.riss.kr/search/detail/DetailView.do...
# 2427  http://www.riss.kr/search/detail/DetailView.do...
# 2428  http://www.riss.kr/search/detail/DetailView.do...
# 2429  http://www.riss.kr/search/detail/DetailView.do...
# 2430  http://www.riss.kr/search/detail/DetailView.do...
#
#                                                      제목  발행연도  \
# 0             빅데이터 유통 생태계에 기반한 단계별 빅데이터 유통 모델 개발에 관한 연구  2016
# 1     실물옵션 기법을 이용한 기업의 빅데이터 기술 도입의 경제적 가치 분석   유유제약 ...  2014
# 2                             빅데이터 에코시스템 기반의 참조 아키텍처 개발  2014
# 3                    공공기관의 빅데이터 성숙도 진단모형 개발 및 적용에 관한 연구  2016
# 4              개인정보 보안강화 및 빅데이터 활성화를 위한 새로운 빅데이터 플랫폼 제시  2016
# ...                                                 ...   ...
# 2426                    융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토  2016
# 2427                           정부기관의 정보열람 요구와    의 협조의무  2016
# 2428                  디지털 플랫폼과   에 의한 국회 전자청원시스템 활성화 연구  2019
# 2429                         천태종 구인사의 종파성 확보를 위한 플랫폼 구도  2019
# 2430                         한국의 데이터주도 혁신에 대한 법의 대응과 진화  2018
#
#                                                     주제어             발행기관  \
# 0     [' 빅데이터 유통 모델 ', ' 데이터 거래 플랫폼 ', ' 빅데이터 거래소 ',...        한국디지털정책학회
# 1     [' 빅데이터 플랫폼 ', ' 실물옵션 ', ' 옵션가치 ', ' 주가 ', ' B...        한국인터넷정보학회
# 2     [' 참조 아키텍처 ', ' 상호운용성 ', ' 표준 ', ' Big data ',...  보안공학연구지원센터(JSE)
# 3                                   [' 성숙도 ', ' 수준진단 ']        한국지역정보화학회
# 4     [' 빅데이터 플랫폼 ', ' 개인정보보호 ', ' 빅데이터 활성화 ', ' HBa...        한국디지털정책학회
# ...                                                 ...              ...
# 2426                                                 []            단국대학교
# 2427                                                 []            경희대학교
# 2428                                                 []           유럽헌법학회
# 2429                                                 []          보조사상연구원
# 2430                                                 []            서울대학교
#
#      상세조회수  다운로드수  KCI피인용횟수
# 0      112    105      13.0
# 1      119    102       5.0
# 2      114     79       NaN
# 3       50     54       1.0
# 4      121     92       6.0
# ...    ...    ...       ...
# 2426     5      4       NaN
# 2427     8      0       1.0
# 2428    10      0       NaN
# 2429     3      0       NaN
# 2430    32     20       5.0
#
# [2431 rows x 8 columns]

# %%
RISS_df
# Out:
#                                                    url  \
# 0    http://www.riss.kr/search/detail/DetailView.do...
# 1    http://www.riss.kr/search/detail/DetailView.do...
# 2    http://www.riss.kr/search/detail/DetailView.do...
# 3    http://www.riss.kr/search/detail/DetailView.do...
# 4    http://www.riss.kr/search/detail/DetailView.do...
# ..                                                 ...
# 638  http://www.riss.kr/search/detail/DetailView.do...
# 639  http://www.riss.kr/search/detail/DetailView.do...
# 640  http://www.riss.kr/search/detail/DetailView.do...
# 641  http://www.riss.kr/search/detail/DetailView.do...
# 642  http://www.riss.kr/search/detail/DetailView.do...
#
#                                                     제목  발행연도  \
# 0                          인공지능 가상비서의 비서직무 수행역량에 대한 연구  2017
# 1    환경에서 다중 사용자와 다중 센서로부터 발생하는 다양한 상황을 처리하기 위한 시스템...  2017
# 2                       복합환승역사 통행자 기반 통합 모빌리티 평가 기법 개발  2017
# 3                              춤을 활용한 차세대 교육플랫폼 구축방안탐구  2017
# 4           텍스트마이닝을 활용한 발달장애 신문기사 분석  조기선별과 조기중재를 중심으로  2020
# ..                                                 ...   ...
# 638                    융복합 시설설치의 원스톱 행정체제 도입에 관한 법적 검토  2016
# 639                           정부기관의 정보열람 요구와    의 협조의무  2016
# 640                  디지털 플랫폼과   에 의한 국회 전자청원시스템 활성화 연구  2019
# 641                         천태종 구인사의 종파성 확보를 위한 플랫폼 구도  2019
# 642                         한국의 데이터주도 혁신에 대한 법의 대응과 진화  2018
#
#                                                    주제어        발행기관  상세조회수  \
# 0    [' 가상비서 ', ' 일반비서 ', ' 선임비서 ', ' 비서직무 ', ' 직무분...      한국비서학회    363
# 1    [' Context-awareness data ', ' Contextual Info...  국제e-비즈니스학회     12
# 2    [' 통합 모빌리티 지표 ', ' 복합환승센터 ', ' 대중교통지향형개발 ', ' ...     한국ITS학회     25
# 3    [' 2015개정 교육과정 ', ' 창의융합형 ', ' 인재양성 ', ' 4차산업시...       한양대학교     45
# 4    [' Developmental disabilities ', ' Early scree...    한국특수아동학회      9
# ..                                                 ...         ...    ...
# 638                                                 []       단국대학교      5
# 639                                                 []       경희대학교      8
# 640                                                 []      유럽헌법학회     10
# 641                                                 []     보조사상연구원      3
# 642                                                 []       서울대학교     32
#
#      다운로드수  KCI피인용횟수
# 0      331       0.0
# 1        3       0.0
# 2       19       NaN
# 3       44       0.0
# 4       22       0.0
# ..     ...       ...
# 638      4       NaN
# 639      0       1.0
# 640      0       NaN
# 641      0       NaN
# 642     20       5.0
#
# [643 rows x 8 columns]

# %%
import matplotlib.pyplot as plt

import seaborn as sns

sns.set(style='darkgrid')

RISS_df.groupby('발행연도').count()['제목'][:-1].plot(kind = 'barh')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 54665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # DB Oracle

# %%
def db_save(RISS_LIST):

    import sqlite3
    from pandas.io import sql
    import os

    with sqlite3.connect(os.path.join('.' , 'sqliteDB')) as con: # sqlite DB 파일이 존재하지 않는 경우 파일생성
        try:
            RISS_LIST.to_sql(name = 'RISS_LIST', con = con, index = False, if_exists='append') 
            #if_exists : {'fail', 'replace', 'append'} default : fail
        except Exception as e:
            print(str(e))
        print(len(RISS_LIST) , '저장 완료 ...')

# %%
def db_select():
    with sqlite3.connect(os.path.join('.','sqliteDB')) as con: # sqlite DB 파일이 존재하지 않는 경우 파일생성
        try:
            query = 'SELECT * FROM RISS_LIST'
            RISS_LIST = pd.read_sql(query, con = con)
        except Exception as e:
            print(str(e)) 
        return RISS_LIST
